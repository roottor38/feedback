# %%
import json, os

import pandas as pd
import numpy as np

from konlpy.tag import Okt
import nltk

from sklearn.model_selection import train_test_split

from keras.models import Sequential, load_model
from keras.layers import Dense 
from keras import optimizers, losses, metrics

# %%
def read_csv():
    # pd로 csv 읽기
    return pd.concat([pd.read_csv("data/neg_opinion12.csv"), pd.read_csv("data/pos_opinion12.csv"),\
                      pd.read_csv("data/neg_opinion19.csv"), pd.read_csv("data/pos_opinion19.csv")])\
            .reset_index().drop('index', axis=1) # 인덱스 초기화

# %%
def check_pos():
    # 이미 형태소 전처리 된 json 파일 있는지 확인
    fname = "pos_tag.json"
    if os.path.isfile(fname):
        print("// 형태소 전처리 파일 존재")
        with open(fname, encoding="utf-8-sig") as f:
            data = pd.DataFrame(json.load(f), columns=["comment", "risk"])
    else: 
        print("// 형태소 전처리 파일 미존재")
        # okt로 형태소 분석하기
        data = read_csv()
        okt = Okt()
        def tokenize(doc):
            return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]
            # norm은 정규화(오타 및 띄어쓰기 교정), stem은 근어화
        data['comment'] = data['comment'].apply(tokenize)
        print("// 형태소 전처리 진행")
        pos_tag = [(data['comment'][i], int(data['risk'][i])) for i in range(len(data))]
        # JSON 파일로 저장
        with open(fname, 'w', encoding="utf-8") as f:
            json.dump(pos_tag, f, ensure_ascii=False, indent="\t")
            print("// 형태소 전처리 파일 생성 완료")
    return data

# %%
check_pos()
# Out:
# // 형태소 전처리 파일 존재
#                                                  comment  risk
# 0      [접속/Noun, 하/Suffix, 자마자/Noun, 제/Modifier, 가가/N...     1
# 1      [엘프/Noun, 궁수/Noun, 하는데/Verb, 4/Number, 렙때/Noun...     1
# 2       [왜/Noun, 안/VerbPrefix, 깔리냐/Verb, ../Punctuation]     1
# 3                  [유/Noun, 져/Verb, 엿/Modifier, 먹임/Verb]     1
# 4                                             [도박장/Noun]     1
# ...                                                  ...   ...
# 46716  [실망/Noun, 시키지/Verb, 않았으면/Verb, .../Punctuation...     0
# 46717                                 [거래소/Noun, 굿/Noun]     0
# 46718                           [굿/Noun, ^^/Punctuation]     0
# 46719                         [최고/Noun, 의/Josa, 게임/Noun]     0
# 46720          [거래소/Noun, 아싸/Exclamation, ~/Punctuation]     0
#
# [46721 rows x 2 columns]

# %%
def word_select(data, num=10000):
    fname = "word_index.json"
    tokens = [token for row in data['comment'] for token in row]
    print("// 고유 단어 :", len(set(tokens)))
    text = nltk.Text(tokens, name='NMSC')#토큰이 몇개 있는지 확인
    selected_words = [t[0] for t in text.vocab().most_common(num)]
    with open(fname, 'w', encoding="utf-8") as f:
        json.dump(selected_words, f, ensure_ascii=False, indent="\t")
        print("// 단어 인덱스 파일 생성 완료")
    return selected_words

# %%
word_select(check_pos())
# Out:
# // 형태소 전처리 파일 존재
# // 고유 단어 : 46614
# // 단어 인덱스 파일 생성 완료
# ['게임/Noun',
#  '이/Josa',
#  './Punctuation',
#  '도/Josa',
#  '?/Punctuation',
#  '가/Josa',
#  '에/Josa',
#  '을/Josa',
#  '../Punctuation',
#  '접속/Noun',
#  '은/Josa',
#  '리니지/Noun',
#  '들/Suffix',
#  '.../Punctuation',
#  '는/Josa',
#  '돈/Noun',
#  '안/VerbPrefix',
#  '현질/Noun',
#  '만/Josa',
#  '를/Josa',
#  '이/Determiner',
#  '으로/Josa',
#  '겜/Noun',
#  '왜/Noun',
#  '의/Josa',
#  '로/Josa',
#  '서버/Noun',
#  '과금/Noun',
#  '좀/Noun',
#  '케릭/Noun',
#  '요/Josa',
#  '유저/Noun',
#  '못/VerbPrefix',
#  '다/Adverb',
#  '하고/Josa',
#  '하/Suffix',
#  '너무/Adverb',
#  '추억/Noun',
#  '하는/Verb',
#  '뭐/Noun',
#  '거/Noun',
#  '유도/Noun',
#  '진짜/Noun',
#  'ㅡㅡ/KoreanParticle',
#  '입니다/Adjective',
#  '최악/Noun',
#  '그냥/Noun',
#  '에서/Josa',
#  '업데이트/Noun',
#  '한/Determiner',
#  '캐릭/Noun',
#  '고/Josa',
#  '계정/Noun',
#  '사람/Noun',
#  '다시/Noun',
#  '캐릭터/Noun',
#  '!/Punctuation',
#  '생각/Noun',
#  '1/Number',
#  '말/Noun',
#  '최고/Noun',
#  'ㅋㅋ/KoreanParticle',
#  '엔씨/Noun',
#  '했는데/Verb',
#  '생/Noun',
#  '하면/Verb',
#  '할/Verb',
#  '굿/Noun',
#  '이/Noun',
#  '삭제/Noun',
#  '계속/Noun',
#  '게/Josa',
#  ',/Punctuation',
#  '개/Noun',
#  '아니/Adjective',
#  '시작/Noun',
#  '아인/Noun',
#  '쓰레기/Noun',
#  '시간/Noun',
#  '것/Noun',
#  '??/Punctuation',
#  '해서/Verb',
#  '성/Suffix',
#  '정말/Noun',
#  '모바일/Noun',
#  '해주세요/Verb',
#  '이건/Noun',
#  '복구/Noun',
#  '좋아요/Adjective',
#  '인데/Josa',
#  '~/Punctuation',
#  '다/Josa',
#  '..../Punctuation',
#  '하지/Verb',
#  '더/Noun',
#  '나/Josa',
#  '까지/Josa',
#  '건지/Verb',
#  '니까/Josa',
#  '한/Josa',
#  '운영/Noun',
#  '요/Noun',
#  '잘/VerbPrefix',
#  '때/Noun',
#  '이다/Josa',
#  '아/Josa',
#  '그래픽/Noun',
#  '하나/Noun',
#  'ㅋ/KoreanParticle',
#  '안되고/Adjective',
#  '내/Noun',
#  '재미/Noun',
#  '라/Josa',
#  '지/Josa',
#  '하고/Verb',
#  '면/Josa',
#  '사/Modifier',
#  'm/Alpha',
#  '어떻게/Adjective',
#  '지금/Noun',
#  '이네/Josa',
#  '임/Noun',
#  '부터/Josa',
#  '장난/Noun',
#  '2/Number',
#  '합니다/Verb',
#  '아/Exclamation',
#  '제한/Noun',
#  '후/Noun',
#  '다운/Noun',
#  '라는/Josa',
#  '인/Josa',
#  '역시/Noun',
#  '템/Noun',
#  '환불/Noun',
#  '오픈/Noun',
#  '무/Noun',
#  '사전예약/Noun',
#  '정도/Noun',
#  '결제/Noun',
#  '안됨/Adjective',
#  '서/Josa',
#  '중/Suffix',
#  '아이템/Noun',
#  '없고/Adjective',
#  '하라/Noun',
#  '기/Modifier',
#  '이나/Josa',
#  'ㅋㅋㅋ/KoreanParticle',
#  '렉/Noun',
#  '하는데/Verb',
#  '그/Determiner',
#  '라고/Josa',
#  '못/Noun',
#  '폰/Noun',
#  '머/Noun',
#  '네/Josa',
#  '실망/Noun',
#  '설치/Noun',
#  '없는/Adjective',
#  '처음/Noun',
#  '적/Suffix',
#  '터/Noun',
#  '냐/Josa',
#  '안/Noun',
#  '빨리/Adverb',
#  '답변/Noun',
#  '과/Josa',
#  '많이/Adverb',
#  '리뷰/Noun',
#  '해/Noun',
#  '섭/Noun',
#  '무슨/Noun',
#  '제/Noun',
#  '!!/Punctuation',
#  '이런/Modifier',
#  '나/Noun',
#  '연동/Noun',
#  '사냥/Noun',
#  '실행/Noun',
#  '^^/Punctuation',
#  '같은/Adjective',
#  '자체/Noun',
#  '몇/Modifier',
#  '패치/Noun',
#  '확인/Noun',
#  '해도/Noun',
#  '답/Noun',
#  'ㅎㅎ/KoreanParticle',
#  '구글/Noun',
#  '거래/Noun',
#  '야/Josa',
#  '내/Determiner',
#  '걸/Noun',
#  '옛날/Noun',
#  '그/Noun',
#  '해야/Verb',
#  '도박/Noun',
#  '5/Number',
#  '기대/Noun',
#  '그리고/Conjunction',
#  '오류/Noun',
#  '로그인/Noun',
#  '죠/Josa',
#  '보다/Josa',
#  '이상/Noun',
#  '안되네요/Adjective',
#  '함/Noun',
#  '이라고/Josa',
#  'nc/Alpha',
#  '해결/Noun',
#  '건가/Noun',
#  '성/Modifier',
#  '저/Noun',
#  '자꾸/Noun',
#  '점검/Noun',
#  '향수/Noun',
#  '없음/Adjective',
#  '행성/Noun',
#  '이라/Josa',
#  '니/Josa',
#  '하세요/Verb',
#  '와/Josa',
#  '한번/Noun',
#  '시스템/Noun',
#  '이벤트/Noun',
#  '잘/Verb',
#  '플레이/Noun',
#  '가요/Noun',
#  '이렇게/Adverb',
#  '들/Verb',
#  '없네요/Adjective',
#  '이고/Josa',
#  '좋은/Adjective',
#  '전/Modifier',
#  '달/Noun',
#  '저/Determiner',
#  '다른/Modifier',
#  '이런/Adjective',
#  '참/Verb',
#  '하게/Verb',
#  '또/Noun',
#  '때문/Noun',
#  '안되는/Adjective',
#  '네/Suffix',
#  '문제/Noun',
#  '게/Noun',
#  '없으면/Adjective',
#  '대/Modifier',
#  '자동/Noun',
#  'ㅠㅠ/KoreanParticle',
#  '별/Noun',
#  '재/Noun',
#  '점/Noun',
#  '아니고/Adjective',
#  '업뎃/Noun',
#  '문의/Noun',
#  '~~/Punctuation',
#  '12/Number',
#  '광고/Noun',
#  '없다/Adjective',
#  '그대로/Noun',
#  '는데/Verb',
#  '마세요/Verb',
#  '이제/Noun',
#  '이후/Noun',
#  '거래소/Noun',
#  '하루/Noun',
#  '오늘/Noun',
#  '다이아/Noun',
#  '뭔/Modifier',
#  'ㅡ/KoreanParticle',
#  '니/Noun',
#  '안되요/Adjective',
#  '대기/Noun',
#  '한다/Verb',
#  '확률/Noun',
#  '없이/Adverb',
#  '해/Verb',
#  '언제/Noun',
#  '화면/Noun',
#  '제/Modifier',
#  '사드/Noun',
#  '햇/Noun',
#  '있는/Adjective',
#  '변신/Noun',
#  '완전/Noun',
#  '도/Noun',
#  '회사/Noun',
#  '이/Suffix',
#  '다운로드/Noun',
#  '전/Noun',
#  'M/Alpha',
#  '접/Noun',
#  '해도/Verb',
#  '하기/Verb',
#  '3/Number',
#  '수/Noun',
#  '노잼/Noun',
#  '버그/Noun',
#  '장비/Noun',
#  'pc/Alpha',
#  '랑/Josa',
#  'ㅎ/KoreanParticle',
#  '된/Verb',
#  '부탁드립니다/Adjective',
#  '퀘스트/Noun',
#  '보상/Noun',
#  '바로/Noun',
#  '팔이/Noun',
#  'ㅠ/KoreanParticle',
#  '아주/Noun',
#  '몹/Noun',
#  '걍/Adverb',
#  '게스트/Noun',
#  '할수/Verb',
#  '등록/Noun',
#  '렙/Noun',
#  '번/Noun',
#  '4/Number',
#  '이냐/Josa',
#  '하네요/Verb',
#  '님/Suffix',
#  '기/Noun',
#  '넘/Verb',
#  '갑자기/Noun',
#  '노가다/Noun',
#  '이유/Noun',
#  '안되는데/Adjective',
#  '제발/Noun',
#  '위/Noun',
#  '어디/Noun',
#  '18/Number',
#  '출시/Noun',
#  '연결/Noun',
#  '앱/Noun',
#  '예전/Noun',
#  '일/Modifier',
#  '...../Punctuation',
#  '제대로/Noun',
#  '하면서/Verb',
#  '하냐/Verb',
#  '아이디/Noun',
#  '사전/Noun',
#  '이랑/Josa',
#  '겁/Noun',
#  '개인/Noun',
#  '세/Noun',
#  'NC/Alpha',
#  '인증/Noun',
#  '전체/Noun',
#  '뜨고/Verb',
#  '???/Punctuation',
#  '되는/Verb',
#  '근데/Adverb',
#  '사용/Noun',
#  '호구/Noun',
#  '와/Verb',
#  '관리/Noun',
#  '안됩니다/Adjective',
#  '10/Number',
#  '끝/Noun',
#  '듯/Noun',
#  '다른/Noun',
#  '레볼루션/Noun',
#  '하/Exclamation',
#  '45/Number',
#  '8/Number',
#  '버전/Noun',
#  '만/Noun',
#  '이용/Noun',
#  '뭘/Noun',
#  '하는게/Verb',
#  '빠른/Adjective',
#  '않고/Verb',
#  '없네/Adjective',
#  '컨트롤/Noun',
#  '절대/Noun',
#  '됨/Verb',
#  '열심히/Adverb',
#  '매크로/Noun',
#  '하다/Verb',
#  '보고/Noun',
#  'ㅜㅜ/KoreanParticle',
#  '조치/Noun',
#  '받고/Verb',
#  '욕/Noun',
#  '여/Josa',
#  '그런/Modifier',
#  'ㅋㅋㅋㅋ/KoreanParticle',
#  '느낌/Noun',
#  '데/Noun',
#  '아님/Adjective',
#  '고객/Noun',
#  '있습니다/Adjective',
#  '주세요/Verb',
#  '가/Verb',
#  '무슨/Modifier',
#  '불가/Noun',
#  '좋네요/Adjective',
#  '뽑기/Noun',
#  '진행/Noun',
#  '인지/Josa',
#  '(/Punctuation',
#  '글/Noun',
#  '!!!/Punctuation',
#  '두/Determiner',
#  '선택/Noun',
#  '난/Noun',
#  '이딴/Modifier',
#  '만든/Verb',
#  '아직/Adverb',
#  '안해/Noun',
#  '되고/Verb',
#  '쳐/Verb',
#  '별/Modifier',
#  '로/Noun',
#  '인가/Josa',
#  '레벨/Noun',
#  '린/Noun',
#  '도안/Noun',
#  '강화/Noun',
#  '이해/Noun',
#  '하다가/Verb',
#  '별로/Noun',
#  '건/Noun',
#  '분/Noun',
#  '아깝다/Adjective',
#  '핸드폰/Noun',
#  '잼/Noun',
#  ')/Punctuation',
#  '공지/Noun',
#  '앞/Noun',
#  '중/Noun',
#  '만들어/Verb',
#  '은/Noun',
#  '캐쉬/Noun',
#  '적당히/Adjective',
#  '노답/Noun',
#  '먹는/Verb',
#  '않/Verb',
#  '좋아/Adjective',
#  '현금/Noun',
#  '방법/Noun',
#  '해라/Verb',
#  '간/Suffix',
#  '에러/Noun',
#  '하던/Verb',
#  '처럼/Josa',
#  '와이파이/Noun',
#  '7/Number',
#  '꿀잼/Noun',
#  '데이터/Noun',
#  '일/Noun',
#  '있는데/Adjective',
#  '차라리/Noun',
#  '용량/Noun',
#  '아예/Noun',
#  '수준/Noun',
#  '오토/Noun',
#  '조작/Noun',
#  '놈/Noun',
#  '어제/Noun',
#  '전부/Noun',
#  '바랍니다/Verb',
#  '는/Verb',
#  '아니면/Adjective',
#  '어/Suffix',
#  '투자/Noun',
#  '재미있네요/Adjective',
#  '평가/Noun',
#  '망겜/Noun',
#  '지/Modifier',
#  '요즘/Noun',
#  '하네/Verb',
#  '빨/Noun',
#  '그래도/Adverb',
#  '안되/Adjective',
#  '안되네/Adjective',
#  '갓/Modifier',
#  '오래/Adverb',
#  '많은/Adjective',
#  '보니/Verb',
#  '알/Noun',
#  '해야지/Verb',
#  '옛/Modifier',
#  '소/Modifier',
#  '이번/Noun',
#  '리/Noun',
#  '처리/Noun',
#  '소리/Noun',
#  '네트워크/Noun',
#  '같아요/Adjective',
#  '재밌어요/Adjective',
#  '지우고/Verb',
#  '창/Noun',
#  '조금/Noun',
#  '네/Determiner',
#  '개돼지/Noun',
#  '작업장/Noun',
#  '마다/Josa',
#  '수정/Noun',
#  '냥/Josa',
#  '모든/Noun',
#  '좋은데/Adjective',
#  '째/Suffix',
#  '이지/Josa',
#  '되야/Verb',
#  '밖에/Josa',
#  '6/Number',
#  '감/Noun',
#  '재미있어요/Adjective',
#  '요정/Noun',
#  '씩/Suffix',
#  '같은데/Adjective',
#  '엄청/Adverb',
#  '하나요/Noun',
#  '같네요/Adjective',
#  ';;/Punctuation',
#  '아무/Modifier',
#  '명/Noun',
#  '없어/Adjective',
#  '재밌네요/Adjective',
#  '먼/Adjective',
#  '기본/Noun',
#  '인생/Noun',
#  '한/Verb',
#  '시/Noun',
#  '일단/Noun',
#  '도대체/Noun',
#  '엔/Josa',
#  '이라도/Josa',
#  '자/Suffix',
#  '진심/Noun',
#  '시/Modifier',
#  '나오고/Verb',
#  '하지만/Conjunction',
#  '평점/Noun',
#  '세/Modifier',
#  '안된다/Adjective',
#  '너/Noun',
#  '처/Noun',
#  '인가요/Josa',
#  '시대/Noun',
#  '변경/Noun',
#  '에는/Josa',
#  '아니라/Adjective',
#  '눈/Noun',
#  '노트/Noun',
#  '랩/Noun',
#  '모든/Modifier',
#  '어찌/Noun',
#  '사라짐/Verb',
#  '여/Noun',
#  '되는데/Verb',
#  '얼마나/Noun',
#  '든/Josa',
#  '구매/Noun',
#  '수고/Noun',
#  '추천/Noun',
#  '이야/Josa',
#  '상점/Noun',
#  '핵/Noun',
#  '기다린/Verb',
#  '드/Noun',
#  '주식/Noun',
#  '만들고/Verb',
#  '기사/Noun',
#  '검/Noun',
#  '쿠폰/Noun',
#  '운영자/Noun',
#  '어느/Modifier',
#  '아무리/Adverb',
#  '할만/Verb',
#  '솔직히/Adjective',
#  '현상/Noun',
#  '한테/Josa',
#  '에요/Josa',
#  '영변/Noun',
#  '구/Noun',
#  '개선/Noun',
#  '무과/Noun',
#  '경우/Noun',
#  '성인/Noun',
#  '친구/Noun',
#  '상자/Noun',
#  '대박/Noun',
#  '하는거/Verb',
#  '래/Josa',
#  '잼나요/Verb',
#  '씨/Noun',
#  '할수가/Verb',
#  '감사합니다/Verb',
#  '하니/Noun',
#  '날/Noun',
#  '할려고/Verb',
#  '본/Modifier',
#  '아덴/Noun',
#  '됩니다/Verb',
#  '고/Noun',
#  '뜨는데/Verb',
#  '기존/Noun',
#  '개판/Noun',
#  '작/Modifier',
#  '50/Number',
#  '너/Modifier',
#  '여기/Noun',
#  '이안/Noun',
#  '짜증/Noun',
#  '신규/Noun',
#  '먹고/Verb',
#  '에도/Josa',
#  '안되나요/Adjective',
#  '짱/Noun',
#  '카드/Noun',
#  '중독/Noun',
#  '가지/Noun',
#  '만하/Noun',
#  '굳/Adjective',
#  '아직도/Adverb',
#  '어쩌/Noun',
#  '새로/Adjective',
#  '주/Modifier',
#  '조차/Josa',
#  '되/Verb',
#  '했던/Verb',
#  '화이팅/Noun',
#  '에게/Josa',
#  '뭔가/Noun',
#  '애/Noun',
#  '좋습니다/Adjective',
#  '좋음/Adjective',
#  '재미있게/Adjective',
#  '바/Noun',
#  '재밌게/Adjective',
#  '식/Noun',
#  '라도/Josa',
#  '지만/Josa',
#  '굿굿/Noun',
#  '이름/Noun',
#  '하지마/Verb',
#  '초반/Noun',
#  '준비/Noun',
#  '하지마라/Verb',
#  '없습니다/Adjective',
#  '하지말라는/Verb',
#  '센터/Noun',
#  '그렇게/Adverb',
#  '동안/Noun',
#  '말고/Josa',
#  '마켓/Noun',
#  '누가/Noun',
#  '부터/Noun',
#  '돼/Verb',
#  '대/Verb',
#  '없어요/Adjective',
#  '어이/Noun',
#  '하자/Noun',
#  's/Alpha',
#  '안되서/Adjective',
#  '분들/Suffix',
#  '함/Verb',
#  '법사/Noun',
#  '해보고/Verb',
#  '했더니/Verb',
#  '구/Modifier',
#  '되게/Adverb',
#  '미친/Adjective',
#  '했다/Verb',
#  '컨텐츠/Noun',
#  '자동사/Noun',
#  '해킹/Noun',
#  '부탁/Noun',
#  '에/Foreign',
#  '지/Verb',
#  '문자/Noun',
#  '뿐/Noun',
#  '댓글/Noun',
#  '남/Noun',
#  '거지/Noun',
#  '택진/Noun',
#  '장/Suffix',
#  '없는데/Adjective',
#  '9/Number',
#  '의/Noun',
#  '같이/Adverb',
#  '뜨네요/Verb',
#  '메/Noun',
#  '보면/Verb',
#  '패키지/Noun',
#  '뒤/Noun',
#  '결국/Adverb',
#  '하니/Verb',
#  '경험치/Noun',
#  '했지만/Verb',
#  '하려고/Verb',
#  '그럼/Adjective',
#  '드랍/Noun',
#  '월/Noun',
#  '같습니다/Adjective',
#  '합/Noun',
#  '정지/Noun',
#  '안대/Noun',
#  '해놓고/Verb',
#  '갑니다/Verb',
#  '있고/Adjective',
#  '있네요/Adjective',
#  '1:1/Number',
#  '있어요/Adjective',
#  '있어서/Adjective',
#  '인형/Noun',
#  '이하/Noun',
#  '마음/Noun',
#  '이따/Noun',
#  '열/Noun',
#  '무기/Noun',
#  '등/Noun',
#  '깔았는데/Verb',
#  '번호/Noun',
#  'PC/Alpha',
#  '역대/Noun',
#  '한게임/Noun',
#  '전화/Noun',
#  '옛/Adverb',
#  '팅기고/Verb',
#  '으로도/Josa',
#  '휴/Exclamation',
#  '똥/Noun',
#  '동/Modifier',
#  '이라는/Josa',
#  '서비스/Noun',
#  '부분/Noun',
#  '깔아도/Verb',
#  '첨/Adverb',
#  '아닌/Adjective',
#  '컴퓨터/Noun',
#  '20년/Number',
#  '축복/Noun',
#  'ㅋㅋㅋㅋㅋ/KoreanParticle',
#  '되지/Verb',
#  '그래서/Adverb',
#  'ㅜ/KoreanParticle',
#  '하는것도/Verb',
#  '금은/Noun',
#  '위해/Noun',
#  '제작/Noun',
#  '깔고/Verb',
#  '팅김/Verb',
#  '사기/Noun',
#  '아니다/Adjective',
#  '기분/Noun',
#  '질/Noun',
#  '안되면/Adjective',
#  '~~~/Punctuation',
#  '정액/Noun',
#  '클릭/Noun',
#  '데포/Noun',
#  '보다/Verb',
#  '12시/Number',
#  '이동/Noun',
#  '드디어/Adverb',
#  '값/Noun',
#  '하지말고/Verb',
#  '상/Suffix',
#  '요청/Noun',
#  '스트레스/Noun',
#  '돼요/Verb',
#  '겁나/Verb',
#  '들어/Verb',
#  '대체/Noun',
#  '무조건/Noun',
#  '엔시/Noun',
#  '정신/Noun',
#  '맛/Noun',
#  '합시다/Verb',
#  '없어서/Adjective',
#  '급/Suffix',
#  '공격/Noun',
#  '줄/Noun',
#  '전혀/Noun',
#  '한/Modifier',
#  '하는지/Verb',
#  '좋고/Adjective',
#  '로딩/Noun',
#  '그냥/Modifier',
#  '젠/Noun',
#  '겨/Noun',
#  '피씨/Noun',
#  '오랜/Modifier',
#  '맘/Noun',
#  '20/Number',
#  '날라/Verb',
#  '기업/Noun',
#  '야/Exclamation',
#  '지웠다/Verb',
#  '코드/Noun',
#  '했습니다/Verb',
#  '크로/Verb',
#  '만드는/Verb',
#  '한마디/Noun',
#  '같다/Adjective',
#  '해요/Verb',
#  '데이/Noun',
#  '종일/Noun',
#  '물약/Noun',
#  '곳/Noun',
#  '이에요/Josa',
#  '및/Noun',
#  '새벽/Noun',
#  '러/Noun',
#  '를/Noun',
#  '몇번/Noun',
#  '하러/Verb',
#  '된다/Verb',
#  '해봤는데/Verb',
#  '부탁드려요/Adjective',
#  '극악/Noun',
#  '이미/Adverb',
#  '두/Josa',
#  '반복/Noun',
#  '안나/Noun',
#  '형/Suffix',
#  '거의/Noun',
#  '되네요/Verb',
#  '매출/Noun',
#  '렙업/Noun',
#  '꼭/Noun',
#  '증발/Noun',
#  '기기/Noun',
#  '과거/Noun',
#  '진/Noun',
#  '업/Noun',
#  '망해라/Adjective',
#  '상태/Noun',
#  '응/Noun',
#  '아닌가요/Adjective',
#  '1시간/Number',
#  '네/Noun',
#  '추가/Noun',
#  '한국/Noun',
#  '쓰고/Verb',
#  '있음/Adjective',
#  '몬스터/Noun',
#  '되면/Verb',
#  '던전/Noun',
#  '되나요/Verb',
#  '해줘요/Verb',
#  '기다렸는데/Verb',
#  '고생/Noun',
#  '신고/Noun',
#  '조/Modifier',
#  '....../Punctuation',
#  '+/Punctuation',
#  '현/Modifier',
#  '되어/Verb',
#  '쓰/Verb',
#  '개도/Noun',
#  '않는/Verb',
#  '나서/Verb',
#  '심함/Adjective',
#  '혹시/Noun',
#  '만에/Josa',
#  '100/Number',
#  '젤/Noun',
#  '영웅/Noun',
#  '사냥터/Noun',
#  '판도라/Noun',
#  '이지만/Josa',
#  'ㅉㅉ/KoreanParticle',
#  '안함/Noun',
#  '발전/Noun',
#  '유/Noun',
#  '팔/Noun',
#  '비/Noun',
#  '고/Modifier',
#  '돼고/Verb',
#  '부사/Noun',
#  '아닌가/Adjective',
#  '양산/Noun',
#  '어떻/Modifier',
#  '만의/Josa',
#  '돈독/Noun',
#  '나름/Noun',
#  '데스/Noun',
#  '망/Noun',
#  '30분/Number',
#  '수/Modifier',
#  '없다고/Adjective',
#  '!!!!/Punctuation',
#  '돈돈/Noun',
#  '모/Noun',
#  '사라졌어요/Verb',
#  '갤럭시/Noun',
#  '안되는건/Adjective',
#  '같음/Adjective',
#  '답글/Noun',
#  '그것/Noun',
#  '현실/Noun',
#  '주고/Verb',
#  '누르면/Verb',
#  '입/Noun',
#  '하는건/Verb',
#  '2017년/Number',
#  '많이/Modifier',
#  '개발자/Noun',
#  '속/Noun',
#  '마/Noun',
#  '드립니다/Verb',
#  '좋/Adjective',
#  '화/Suffix',
#  '인거/Josa',
#  '종료/Noun',
#  '쓰는/Verb',
#  '뿐/Suffix',
#  '않네요/Verb',
#  '같이/Josa',
#  '놔/Verb',
#  '린지/Noun',
#  '잘못/Noun',
#  '만/Suffix',
#  '아데나/Noun',
#  '인간/Noun',
#  '초기/Noun',
#  '저만/Modifier',
#  '로만/Noun',
#  '되서/Verb',
#  '받았는데/Verb',
#  '성도/Noun',
#  '타/Modifier',
#  '있게/Adjective',
#  '차이/Noun',
#  '설정/Noun',
#  '중국/Noun',
#  '자/Noun',
#  '똑바로/Noun',
#  'G/Alpha',
#  '손/Noun',
#  '해본/Verb',
#  '최소/Noun',
#  '티/Noun',
#  '배/Noun',
#  '넘게/Verb',
#  '다야/Noun',
#  '기억/Noun',
#  '스킬/Noun',
#  '있다/Adjective',
#  '음/Noun',
#  '현재/Noun',
#  '연/Modifier',
#  '힘든/Adjective',
#  '원래/Noun',
#  '얼마/Noun',
#  '인원/Noun',
#  '큰/Verb',
#  '될/Verb',
#  '재밋/Noun',
#  '휴대폰/Noun',
#  '나와서/Verb',
#  '대로/Josa',
#  '밝히는/Verb',
#  '팔/Modifier',
#  '졋/Noun',
#  '무한/Noun',
#  '개발/Noun',
#  '된거/Noun',
#  '나도/Verb',
#  '아침/Noun',
#  '보람/Noun',
#  '봅니다/Verb',
#  '거기/Noun',
#  '30/Number',
#  '그런데/Conjunction',
#  '한다고/Verb',
#  '퀘/Noun',
#  '접는다/Verb',
#  '계정연/Noun',
#  '모두/Noun',
#  '신경/Noun',
#  '나옴/Verb',
#  '만/Modifier',
#  '사라/Noun',
#  '미/Adjective',
#  '불법/Noun',
#  '움/Noun',
#  '씨/Suffix',
#  '짓/Noun',
#  '안되냐/Adjective',
#  '마리/Noun',
#  '막피/Noun',
#  '그만/Adverb',
#  '판/Noun',
#  '감성/Noun',
#  '버튼/Noun',
#  '어플/Noun',
#  '터치/Noun',
#  '할수있게/Verb',
#  '언/Modifier',
#  '믿고/Verb',
#  '예상/Noun',
#  '짱/VerbPrefix',
#  ...]

# %%
def counter_vect(data, word_index):
    print("// 워드 인덱스 정리 & 데이터 float화 진행")
    def term_frequency(doc):
        return [doc.count(word) for word in word_index]
    pre_data = np.asarray([term_frequency(d) for d in list(data['comment'])]).astype('float32')
    pre_label = data['risk'].astype('float32')
    print("// 전처리 최종 완료")
    return (pre_data, pre_label)

# %%
def deep_learning(dataset):
    train_data, test_data, train_label, test_label = train_test_split(dataset[0], dataset[1])
    
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))#모델 추가및 재거

    model.compile(optimizer=optimizers.RMSprop(lr=0.001),##
             loss=losses.binary_crossentropy,
             metrics=[metrics.binary_accuracy])

    model.fit(train_data, train_label, epochs=100,batch_size=512)   
    print("// 평가 :", model.evaluate(test_data, test_label))
    print("// 모델 저장 완료") 
    model.save('model.test')
    return model

# %%
data = check_pos()
word_index = word_select(data)
dataset = counter_vect(data, word_index)
# Out:
# // 형태소 전처리 파일 존재
# // 고유 단어 : 46614
# // 단어 인덱스 파일 생성 완료
# // 워드 인덱스 정리 & 데이터 float화 진행
# // 전처리 최종 완료

# %%
model = deep_learning(dataset)
# Out:
# Epoch 1/100
# 35040/35040 [==============================] - 3s 88us/step - loss: 0.4608 - binary_accuracy: 0.8037
# Epoch 2/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.2887 - binary_accuracy: 0.8909
# Epoch 3/100
# 35040/35040 [==============================] - 3s 80us/step - loss: 0.2341 - binary_accuracy: 0.9082
# Epoch 4/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.2032 - binary_accuracy: 0.9211
# Epoch 5/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.1793 - binary_accuracy: 0.9313
# Epoch 6/100
# 35040/35040 [==============================] - 3s 80us/step - loss: 0.1594 - binary_accuracy: 0.9419
# Epoch 7/100
# 35040/35040 [==============================] - 3s 80us/step - loss: 0.1420 - binary_accuracy: 0.9493: 1s - loss: 0.1352 - bin
# Epoch 8/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.1267 - binary_accuracy: 0.9551
# Epoch 9/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.1133 - binary_accuracy: 0.9601
# Epoch 10/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.1017 - binary_accuracy: 0.9640
# Epoch 11/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0917 - binary_accuracy: 0.9674
# Epoch 12/100
# 35040/35040 [==============================] - 3s 83us/step - loss: 0.0829 - binary_accuracy: 0.9707
# Epoch 13/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0751 - binary_accuracy: 0.9729
# Epoch 14/100
# 35040/35040 [==============================] - 3s 83us/step - loss: 0.0684 - binary_accuracy: 0.9755
# Epoch 15/100
# 35040/35040 [==============================] - 3s 76us/step - loss: 0.0623 - binary_accuracy: 0.9776
# Epoch 16/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.0572 - binary_accuracy: 0.9793
# Epoch 17/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0534 - binary_accuracy: 0.9811
# Epoch 18/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0491 - binary_accuracy: 0.9822
# Epoch 19/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.0462 - binary_accuracy: 0.9832
# Epoch 20/100
# 35040/35040 [==============================] - 3s 85us/step - loss: 0.0439 - binary_accuracy: 0.9844
# Epoch 21/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0416 - binary_accuracy: 0.9856
# Epoch 22/100
# 35040/35040 [==============================] - 3s 86us/step - loss: 0.0398 - binary_accuracy: 0.9858: 1s - loss: 0.0394 - binary_
# Epoch 23/100
# 35040/35040 [==============================] - 3s 85us/step - loss: 0.0384 - binary_accuracy: 0.9864
# Epoch 24/100
# 35040/35040 [==============================] - 3s 86us/step - loss: 0.0367 - binary_accuracy: 0.9868
# Epoch 25/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.0356 - binary_accuracy: 0.9872
# Epoch 26/100
# 35040/35040 [==============================] - 3s 87us/step - loss: 0.0348 - binary_accuracy: 0.9875: 0s - loss: 0.0342 - binary_accuracy:
# Epoch 27/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0337 - binary_accuracy: 0.9878: 0s - loss: 0.0338 - binary_accuracy: 0.9
# Epoch 28/100
# 35040/35040 [==============================] - 3s 90us/step - loss: 0.0340 - binary_accuracy: 0.9878
# Epoch 29/100
# 35040/35040 [==============================] - 3s 84us/step - loss: 0.0325 - binary_accuracy: 0.9883
# Epoch 30/100
# 35040/35040 [==============================] - 3s 90us/step - loss: 0.0317 - binary_accuracy: 0.9883
# Epoch 31/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.0314 - binary_accuracy: 0.9885
# Epoch 32/100
# 35040/35040 [==============================] - 3s 87us/step - loss: 0.0310 - binary_accuracy: 0.9885
# Epoch 33/100
# 35040/35040 [==============================] - 3s 83us/step - loss: 0.0303 - binary_accuracy: 0.9889
# Epoch 34/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.0297 - binary_accuracy: 0.9892
# Epoch 35/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0296 - binary_accuracy: 0.9891
# Epoch 36/100
# 35040/35040 [==============================] - 3s 91us/step - loss: 0.0291 - binary_accuracy: 0.9890
# Epoch 37/100
# 35040/35040 [==============================] - 3s 83us/step - loss: 0.0299 - binary_accuracy: 0.9888
# Epoch 38/100
# 35040/35040 [==============================] - 3s 85us/step - loss: 0.0288 - binary_accuracy: 0.9892
# Epoch 39/100
# 35040/35040 [==============================] - 3s 85us/step - loss: 0.0284 - binary_accuracy: 0.9896
# Epoch 40/100
# 35040/35040 [==============================] - 3s 89us/step - loss: 0.0283 - binary_accuracy: 0.9893
# Epoch 41/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0278 - binary_accuracy: 0.9894
# Epoch 42/100
# 35040/35040 [==============================] - 3s 83us/step - loss: 0.0280 - binary_accuracy: 0.9895
# Epoch 43/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0275 - binary_accuracy: 0.9895
# Epoch 44/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.0278 - binary_accuracy: 0.9896
# Epoch 45/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0271 - binary_accuracy: 0.9899
# Epoch 46/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.0270 - binary_accuracy: 0.9897
# Epoch 47/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0270 - binary_accuracy: 0.9895
# Epoch 48/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.0268 - binary_accuracy: 0.9898
# Epoch 49/100
# 35040/35040 [==============================] - 3s 85us/step - loss: 0.0266 - binary_accuracy: 0.9898
# Epoch 50/100
# 35040/35040 [==============================] - 3s 92us/step - loss: 0.0265 - binary_accuracy: 0.9901
# Epoch 51/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0265 - binary_accuracy: 0.9898
# Epoch 52/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0265 - binary_accuracy: 0.9898
# Epoch 53/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.0261 - binary_accuracy: 0.9900
# Epoch 54/100
# 35040/35040 [==============================] - 3s 86us/step - loss: 0.0261 - binary_accuracy: 0.9898
# Epoch 55/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0260 - binary_accuracy: 0.9900
# Epoch 56/100
# 35040/35040 [==============================] - 3s 83us/step - loss: 0.0258 - binary_accuracy: 0.9900
# Epoch 57/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.0256 - binary_accuracy: 0.9901
# Epoch 58/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0257 - binary_accuracy: 0.9900
# Epoch 59/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0256 - binary_accuracy: 0.9902
# Epoch 60/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0255 - binary_accuracy: 0.9900
# Epoch 61/100
# 35040/35040 [==============================] - 3s 84us/step - loss: 0.0255 - binary_accuracy: 0.9899
# Epoch 62/100
# 35040/35040 [==============================] - 3s 80us/step - loss: 0.0254 - binary_accuracy: 0.9900
# Epoch 63/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0255 - binary_accuracy: 0.9902
# Epoch 64/100
# 35040/35040 [==============================] - 3s 86us/step - loss: 0.0252 - binary_accuracy: 0.9904
# Epoch 65/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0252 - binary_accuracy: 0.9904
# Epoch 66/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0251 - binary_accuracy: 0.9904: 2s - loss: 0.0
# Epoch 67/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.0250 - binary_accuracy: 0.9904
# Epoch 68/100
# 35040/35040 [==============================] - 3s 83us/step - loss: 0.0250 - binary_accuracy: 0.9902
# Epoch 69/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.0253 - binary_accuracy: 0.9904
# Epoch 70/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.0249 - binary_accuracy: 0.9903
# Epoch 71/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0251 - binary_accuracy: 0.9901
# Epoch 72/100
# 35040/35040 [==============================] - 3s 83us/step - loss: 0.0246 - binary_accuracy: 0.9905
# Epoch 73/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0249 - binary_accuracy: 0.9902
# Epoch 74/100
# 35040/35040 [==============================] - 3s 80us/step - loss: 0.0248 - binary_accuracy: 0.9902
# Epoch 75/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0246 - binary_accuracy: 0.9903
# Epoch 76/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0245 - binary_accuracy: 0.9903
# Epoch 77/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0247 - binary_accuracy: 0.9902
# Epoch 78/100
# 35040/35040 [==============================] - 3s 80us/step - loss: 0.0247 - binary_accuracy: 0.9904
# Epoch 79/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0245 - binary_accuracy: 0.9904
# Epoch 80/100
# 35040/35040 [==============================] - 3s 80us/step - loss: 0.0245 - binary_accuracy: 0.9904
# Epoch 81/100
# 35040/35040 [==============================] - 3s 76us/step - loss: 0.0246 - binary_accuracy: 0.9902
# Epoch 82/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0249 - binary_accuracy: 0.9904
# Epoch 83/100
# 35040/35040 [==============================] - 3s 82us/step - loss: 0.0243 - binary_accuracy: 0.9905
# Epoch 84/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0245 - binary_accuracy: 0.9904
# Epoch 85/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0244 - binary_accuracy: 0.9903
# Epoch 86/100
# 35040/35040 [==============================] - 3s 85us/step - loss: 0.0243 - binary_accuracy: 0.9905
# Epoch 87/100
# 35040/35040 [==============================] - 3s 77us/step - loss: 0.0243 - binary_accuracy: 0.9903
# Epoch 88/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0242 - binary_accuracy: 0.9905
# Epoch 89/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.0243 - binary_accuracy: 0.9902
# Epoch 90/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.0242 - binary_accuracy: 0.9905
# Epoch 91/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0241 - binary_accuracy: 0.9904
# Epoch 92/100
# 35040/35040 [==============================] - ETA: 0s - loss: 0.0243 - binary_accuracy: 0.990 - 3s 80us/step - loss: 0.0243 - binary_accuracy: 0.9906
# Epoch 93/100
# 35040/35040 [==============================] - 3s 81us/step - loss: 0.0242 - binary_accuracy: 0.9904
# Epoch 94/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0241 - binary_accuracy: 0.9906
# Epoch 95/100
# 35040/35040 [==============================] - 3s 78us/step - loss: 0.0241 - binary_accuracy: 0.9905
# Epoch 96/100
# 35040/35040 [==============================] - 3s 80us/step - loss: 0.0241 - binary_accuracy: 0.9904
# Epoch 97/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0241 - binary_accuracy: 0.9906
# Epoch 98/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0239 - binary_accuracy: 0.9906
# Epoch 99/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0241 - binary_accuracy: 0.9906
# Epoch 100/100
# 35040/35040 [==============================] - 3s 79us/step - loss: 0.0239 - binary_accuracy: 0.9904
# 11681/11681 [==============================] - 1s 81us/step
# // 평가 : [2.5181167927310644, 0.842992901802063]
# // 모델 저장 완료

# %%
model = load_model("model.h5")

# %%
def predict_risk(doc, word_index, model):
    okt = Okt()
    def tokenize(doc):
        return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]
        # norm은 정규화(오타 및 띄어쓰기 교정), stem은 근어화
    token = tokenize(doc)
    data = np.expand_dims(np.asarray([token.count(word) for word in word_index]).astype('float32'), axis=0)
    score = float(model.predict(data))
    print("[{}]의 위험 지수는 {:.2f}% 입니다.\n".format(doc, score * 100))

# %%
predict_risk("요정 사기다", word_index, model)
# Out:
# [요정 사기다]의 위험 지수는 27.22% 입니다.

# %%
predict_risk("최소 8강12회정도는 만들어논 사람들은 어케함? 돌리면 마이너스 될거 같은데 ㅡㅡ",word_index, model)
# Out:
# [최소 8강12회정도는 만들어논 사람들은 어케함? 돌리면 마이너스 될거 같은데 ㅡㅡ]의 위험 지수는 100.00% 입니다.

# %%
predict_risk("신검 접속했는데세인트 카운터가 계속 터지더라 피가 안달아ㅋㅋㅋ 그래서 미친하고 오늘 접속했는데 평상시 보나 물약을 200개나 더 먹어 ㅅㅂ 이렇게 지들 멋대로 확률 올렸다 내렸다해도 되는거임??? 쓰레기식희들...",word_index, model)
# Out:
# [신검 접속했는데세인트 카운터가 계속 터지더라 피가 안달아ㅋㅋㅋ 그래서 미친하고 오늘 접속했는데 평상시 보나 물약을 200개나 더 먹어 ㅅㅂ 이렇게 지들 멋대로 확률 올렸다 내렸다해도 되는거임??? 쓰레기식희들...]의 위험 지수는 0.00% 입니다.

# %%
predict_risk("농사서버 기웃거리는 형들을 위한 희소식",word_index, model)
# Out:
# [농사서버 기웃거리는 형들을 위한 희소식]의 위험 지수는 0.00% 입니다.

# %%
#서버 홍보 이야기
predict_risk("농사꾼형들. 팩트만 알려줄께 아툰 그랜드 끝난거 알제? 아툰9섭은 라인이 다 이전가서 라인이없음.. 이번주 중립이 3성 각임.87렙 초반이 3별 거뜬함. 노 통제 서버임.농사꾼형들 초대합니다.ㅡ 아.. 감옥 서버라고 걱정하거나 ,왜 글 쓰냐고 말하는 형들에게..농사는 개조은데, 사람이 없어서 템거래가 ..그래서 난 라인들말구 중립 농사형들이 왔음 좋겠엉세상 어느 시골에 라인없고 노통제 서버 봤음??글구, 담 그랜드 알제? 어느감옥이든 티켓타고 그냥 나가는거.농사는 한철이야 형들.통제 없는 우리서버로와. 라인형들 말구 ㅡㅡ",word_index, model)
# Out:
# [농사꾼형들. 팩트만 알려줄께 아툰 그랜드 끝난거 알제? 아툰9섭은 라인이 다 이전가서 라인이없음.. 이번주 중립이 3성 각임.87렙 초반이 3별 거뜬함. 노 통제 서버임.농사꾼형들 초대합니다.ㅡ 아.. 감옥 서버라고 걱정하거나 ,왜 글 쓰냐고 말하는 형들에게..농사는 개조은데, 사람이 없어서 템거래가 ..그래서 난 라인들말구 중립 농사형들이 왔음 좋겠엉세상 어느 시골에 라인없고 노통제 서버 봤음??글구, 담 그랜드 알제? 어느감옥이든 티켓타고 그냥 나가는거.농사는 한철이야 형들.통제 없는 우리서버로와. 라인형들 말구 ㅡㅡ]의 위험 지수는 100.00% 입니다.

# %%
#버그 관련 이야기
predict_risk("대박 유튜브 대만인? 자기서버? 방송하는거 보는데 몬스터 체력이보임 ㅋㅋㅋ공격하면 피도 닳는거도 보임 대박 뭔 버그 프로그램을 쓰는거야 ㅋㅋ 이런거 처음봄pvp할때도 상대방 체력 보이는거 아님? ㅋㅋ",word_index, model)
# Out:
# [대박 유튜브 대만인? 자기서버? 방송하는거 보는데 몬스터 체력이보임 ㅋㅋㅋ공격하면 피도 닳는거도 보임 대박 뭔 버그 프로그램을 쓰는거야 ㅋㅋ 이런거 처음봄pvp할때도 상대방 체력 보이는거 아님? ㅋㅋ]의 위험 지수는 100.00% 입니다.

# %%
#안좋은거 건졌다는 이야기
predict_risk("8면갑 8무갑(각인) 7보망 날리고 8완부(각인) 건졌는데 이득임? 근데 각인임 시발",word_index, model)
# Out:
# [8면갑 8무갑(각인) 7보망 날리고 8완부(각인) 건졌는데 이득임? 근데 각인임 시발]의 위험 지수는 100.00% 입니다.

# %%
predict_risk("택진",word_index, model)
# Out:
# [택진]의 위험 지수는 50.66% 입니다.

# %%
predict_risk("영자야 겜이 3년째 가고있으면 내가봤을때 교환기능은 한 3년뒤에나 나올거같고 그러면 캐릭터 눌렀을때 우측에 있는 '교환'이라는 문구는  그냥 없애주던가 ^ㅗ^ 아니면 땕쉙읉떩뿕 이딴거 신고좀 편하게 하게 되지도 않는 교환기능 빼고 신고하기로 바꿔주던가 좀 일 좀 해 c8 좀 패키지나 처 만들생각 하지말고  진또배기 유저들 잡을 생각해야지 매크로 살려둬서 니네들이 득 본게 피니지때도 그렇고 있긴허냐?",word_index, model)
# Out:
# [영자야 겜이 3년째 가고있으면 내가봤을때 교환기능은 한 3년뒤에나 나올거같고 그러면 캐릭터 눌렀을때 우측에 있는 '교환'이라는 문구는  그냥 없애주던가 ^ㅗ^ 아니면 땕쉙읉떩뿕 이딴거 신고좀 편하게 하게 되지도 않는 교환기능 빼고 신고하기로 바꿔주던가 좀 일 좀 해 c8 좀 패키지나 처 만들생각 하지말고  진또배기 유저들 잡을 생각해야지 매크로 살려둬서 니네들이 득 본게 피니지때도 그렇고 있긴허냐?]의 위험 지수는 100.00% 입니다.

# %%
predict_risk("오늘 컬렉도전할껀데 러쉬해보신분들 뭐가 더 띄우기 힘든지 알려주시면 감사하겠습니다.. 느낌상 8갑옷이 더 힘들거같긴한데..",word_index, model)
# Out:
# [오늘 컬렉도전할껀데 러쉬해보신분들 뭐가 더 띄우기 힘든지 알려주시면 감사하겠습니다.. 느낌상 8갑옷이 더 힘들거같긴한데..]의 위험 지수는 100.00% 입니다.

# %%
predict_risk("형님들 걍 이반 시세 얼마임?",word_index, model)
# Out:
# [형님들 걍 이반 시세 얼마임?]의 위험 지수는 100.00% 입니다.

# %%
predict_risk("택진이 돈에 환장했네 ",word_index, model)
# Out:
# [택진이 돈에 환장했네 ]의 위험 지수는 37.65% 입니다.

# %%
predict_risk('''신성검사 세인트 카운터 발동확률 급상승한듯 합니다.
머리위에 방패가 계속 뜨면서 힐이 계속 들어가네요
확률 조정한답시고 묻지마 상향 했는데 수치를 잘못 건들인듯합니다 ㅋㅋㅋㅋㅋㅋㅋ
빠른 긴급점검 부탁드립니다''',word_index, model)
# Out:
# [신성검사 세인트 카운터 발동확률 급상승한듯 합니다.
# 머리위에 방패가 계속 뜨면서 힐이 계속 들어가네요
# 확률 조정한답시고 묻지마 상향 했는데 수치를 잘못 건들인듯합니다 ㅋㅋㅋㅋㅋㅋㅋ
# 빠른 긴급점검 부탁드립니다]의 위험 지수는 0.00% 입니다.

# %%
predict_risk('''신성검사 세인트 카운터 발동확률 급상승한듯 합니다.
머리위에 방패가 계속 뜨면서 힐이 계속 들어가네요
확률 조정한답시고 묻지마 상향 했는데 수치를 잘못 건들인듯합니다 ㅋㅋㅋㅋㅋㅋㅋ
빠른 긴급점검 부탁드립니다''',word_index, model)
# Out:
# [신성검사 세인트 카운터 발동확률 급상승한듯 합니다.
# 머리위에 방패가 계속 뜨면서 힐이 계속 들어가네요
# 확률 조정한답시고 묻지마 상향 했는데 수치를 잘못 건들인듯합니다 ㅋㅋㅋㅋㅋㅋㅋ
# 빠른 긴급점검 부탁드립니다]의 위험 지수는 0.00% 입니다.

# %%
predict_risk('''크리스마스 방어구에서 첫타에 나왔어요.....
드다상자에서 반역자의방패 나오고...이번엔.....신완각을 주네요.....
이러니...리니지를 벗어나지를 못하지 ㅠㅠ정말.....''',word_index, model)
# Out:
# [크리스마스 방어구에서 첫타에 나왔어요.....
# 드다상자에서 반역자의방패 나오고...이번엔.....신완각을 주네요.....
# 이러니...리니지를 벗어나지를 못하지 ㅠㅠ정말.....]의 위험 지수는 100.00% 입니다.

# %%
predict_risk('''뭐 리니지m 하시는 분들한테는 그저익숙한 게임속 풍경이긴 하겟지요.
장관이긴 합니다. 월보시간이면 아덴월드 마을에 복귀해서우수수 날아가는 장면들로서스섬도 뭐 장난아니고기란던전이야 작업장의 천국이 된지는 오래고요.
어차피 매크로는 치면 날라가는데 그나마중립유저들 가끔 희귀라도 빼먹는 파우스트 패치 ㅎㅎ''',word_index, model)
# Out:
# [뭐 리니지m 하시는 분들한테는 그저익숙한 게임속 풍경이긴 하겟지요.
# 장관이긴 합니다. 월보시간이면 아덴월드 마을에 복귀해서우수수 날아가는 장면들로서스섬도 뭐 장난아니고기란던전이야 작업장의 천국이 된지는 오래고요.
# 어차피 매크로는 치면 날라가는데 그나마중립유저들 가끔 희귀라도 빼먹는 파우스트 패치 ㅎㅎ]의 위험 지수는 100.00% 입니다.

# %%
predict_risk(''' 일기장 12개 모았는데 첫완부로 뜨네요.
나머지 일기장은 일단 킵해야겠어요.
신검인데 신발졸업해서 기쁩니다.''',word_index, model)
# Out:
# [ 일기장 12개 모았는데 첫완부로 뜨네요.
# 나머지 일기장은 일단 킵해야겠어요.
# 신검인데 신발졸업해서 기쁩니다.]의 위험 지수는 100.00% 입니다.
