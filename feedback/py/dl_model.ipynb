# %%
import json, os

import pandas as pd
import numpy as np

from konlpy.tag import Okt
import nltk

from sklearn.model_selection import train_test_split

from keras.models import Sequential, load_model
from keras.layers import Dense 
from keras import optimizers, losses, metrics

# %%
def read_csv():
    # pd로 csv 읽기
    return pd.concat([pd.read_csv("data/neg_opinion12.csv"), pd.read_csv("data/pos_opinion12.csv"),\
                      pd.read_csv("data/neg_opinion19.csv"), pd.read_csv("data/pos_opinion19.csv")])\
            .reset_index().drop('index', axis=1) # 인덱스 초기화

# %%
def check_pos():
    # 이미 형태소 전처리 된 json 파일 있는지 확인
    fname = "pos_tag.json"
    if os.path.isfile(fname):
        print("// 형태소 전처리 파일 존재")
        with open(fname, encoding="utf-8-sig") as f:
            data = pd.DataFrame(json.load(f), columns=["comment", "risk"])
    else: 
        print("// 형태소 전처리 파일 미존재")
        # okt로 형태소 분석하기
        data = read_csv()
        okt = Okt()
        def tokenize(doc):
            return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]
            # norm은 정규화(오타 및 띄어쓰기 교정), stem은 근어화
        data['comment'] = data['comment'].apply(tokenize)
        print("// 형태소 전처리 진행")
        pos_tag = [(data['comment'][i], int(data['risk'][i])) for i in range(len(data))]
        # JSON 파일로 저장
        with open(fname, 'w', encoding="utf-8") as f:
            json.dump(pos_tag, f, ensure_ascii=False, indent="\t")
            print("// 형태소 전처리 파일 생성 완료")
    return data

# %%
def word_select(data, num=10000):
    fname = "word_index.json"
    tokens = [token for row in data['comment'] for token in row]
    print("// 고유 단어 :", len(set(tokens)))
    text = nltk.Text(tokens, name='NMSC')
    selected_words = [t[0] for t in text.vocab().most_common(num)]
    with open(fname, 'w', encoding="utf-8") as f:
        json.dump(selected_words, f, ensure_ascii=False, indent="\t")
        print("// 단어 인덱스 파일 생성 완료")
    return selected_words

# %%
def counter_vect(data, word_index):
    print("// 워드 인덱스 정리 & 데이터 float화 진행")
    def term_frequency(doc):
        return [doc.count(word) for word in word_index]
    pre_data = np.asarray([term_frequency(d) for d in list(data['comment'])]).astype('float32')
    pre_label = data['risk'].astype('float32')
    print("// 전처리 최종 완료")
    return (pre_data, pre_label)

# %%
def deep_learning(dataset):
    train_data, test_data, train_label, test_label = train_test_split(dataset[0], dataset[1])
    
    model = Sequential()
    model.add(Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(optimizer=optimizers.RMSprop(lr=0.001),
             loss=losses.binary_crossentropy,
             metrics=[metrics.binary_accuracy])

    model.fit(train_data, train_label, epochs=100,batch_size=512)   
    print("// 평가 :", model.evaluate(test_data, test_label))
    print("// 모델 저장 완료") 
    model.save('model.h5')
    return model

# %%
data = check_pos()
word_index = word_select(data)
dataset = counter_vect(data, word_index)
# Out:
# // 형태소 전처리 파일 존재
# // 고유 단어 :  20752
# // 단어 인덱스 파일 생성 완료
# // 워드 인덱스 정리 & 데이터 float화 진행
# // 전처리 최종 완료

# %%
model = deep_learning(dataset)
# Out:
# Epoch 1/100
# 35040/35040 [==============================] - 5s 148us/step - loss: 0.4469 - binary_accuracy: 0.8199
# Epoch 2/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.2958 - binary_accuracy: 0.8895
# Epoch 3/100
# 35040/35040 [==============================] - 5s 146us/step - loss: 0.2518 - binary_accuracy: 0.9023
# Epoch 4/100
# 35040/35040 [==============================] - 5s 144us/step - loss: 0.2252 - binary_accuracy: 0.9129
# Epoch 5/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.2034 - binary_accuracy: 0.9213
# Epoch 6/100
# 35040/35040 [==============================] - 5s 143us/step - loss: 0.1845 - binary_accuracy: 0.9312
# Epoch 7/100
# 35040/35040 [==============================] - 5s 144us/step - loss: 0.1670 - binary_accuracy: 0.9377
# Epoch 8/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.1504 - binary_accuracy: 0.9451
# Epoch 9/100
# 35040/35040 [==============================] - 5s 136us/step - loss: 0.1355 - binary_accuracy: 0.9519
# Epoch 10/100
# 35040/35040 [==============================] - 5s 136us/step - loss: 0.1216 - binary_accuracy: 0.9573
# Epoch 11/100
# 35040/35040 [==============================] - 5s 146us/step - loss: 0.1094 - binary_accuracy: 0.9625
# Epoch 12/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0981 - binary_accuracy: 0.9658
# Epoch 13/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0882 - binary_accuracy: 0.9697
# Epoch 14/100
# 35040/35040 [==============================] - 5s 136us/step - loss: 0.0794 - binary_accuracy: 0.9735
# Epoch 15/100
# 35040/35040 [==============================] - 5s 152us/step - loss: 0.0717 - binary_accuracy: 0.9761 2s - loss: 0.0692 - binary_accuracy - ETA: 1s - loss: 0.0692 -
# Epoch 16/100
# 35040/35040 [==============================] - 3s 86us/step - loss: 0.0655 - binary_accuracy: 0.9784: 2s - loss: 0.061
# Epoch 17/100
# 35040/35040 [==============================] - 3s 91us/step - loss: 0.0602 - binary_accuracy: 0.9803
# Epoch 18/100
# 35040/35040 [==============================] - 5s 138us/step - loss: 0.0553 - binary_accuracy: 0.9822
# Epoch 19/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.0515 - binary_accuracy: 0.9829
# Epoch 20/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0483 - binary_accuracy: 0.9838
# Epoch 21/100
# 35040/35040 [==============================] - 5s 137us/step - loss: 0.0453 - binary_accuracy: 0.9850
# Epoch 22/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.0430 - binary_accuracy: 0.9858
# Epoch 23/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.0408 - binary_accuracy: 0.9859
# Epoch 24/100
# 35040/35040 [==============================] - 5s 143us/step - loss: 0.0390 - binary_accuracy: 0.9870
# Epoch 25/100
# 35040/35040 [==============================] - 5s 138us/step - loss: 0.0381 - binary_accuracy: 0.9871
# Epoch 26/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0368 - binary_accuracy: 0.9876
# Epoch 27/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0352 - binary_accuracy: 0.9876
# Epoch 28/100
# 35040/35040 [==============================] - 5s 137us/step - loss: 0.0346 - binary_accuracy: 0.9880
# Epoch 29/100
# 35040/35040 [==============================] - 5s 140us/step - loss: 0.0335 - binary_accuracy: 0.9880
# Epoch 30/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.0330 - binary_accuracy: 0.9881
# Epoch 31/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.0319 - binary_accuracy: 0.9886
# Epoch 32/100
# 35040/35040 [==============================] - 5s 138us/step - loss: 0.0312 - binary_accuracy: 0.9890
# Epoch 33/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0310 - binary_accuracy: 0.9886
# Epoch 34/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0304 - binary_accuracy: 0.9891
# Epoch 35/100
# 35040/35040 [==============================] - 5s 137us/step - loss: 0.0301 - binary_accuracy: 0.9890
# Epoch 36/100
# 35040/35040 [==============================] - 5s 139us/step - loss: 0.0294 - binary_accuracy: 0.9893
# Epoch 37/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0292 - binary_accuracy: 0.9896
# Epoch 38/100
# 35040/35040 [==============================] - 5s 139us/step - loss: 0.0284 - binary_accuracy: 0.9899
# Epoch 39/100
# 35040/35040 [==============================] - 5s 135us/step - loss: 0.0283 - binary_accuracy: 0.9898
# Epoch 40/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0279 - binary_accuracy: 0.9895
# Epoch 41/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0280 - binary_accuracy: 0.9898
# Epoch 42/100
# 35040/35040 [==============================] - 5s 137us/step - loss: 0.0273 - binary_accuracy: 0.9900
# Epoch 43/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.0270 - binary_accuracy: 0.9902
# Epoch 44/100
# 35040/35040 [==============================] - 5s 143us/step - loss: 0.0268 - binary_accuracy: 0.9902
# Epoch 45/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.0266 - binary_accuracy: 0.9903
# Epoch 46/100
# 35040/35040 [==============================] - 5s 138us/step - loss: 0.0263 - binary_accuracy: 0.9904
# Epoch 47/100
# 35040/35040 [==============================] - 5s 140us/step - loss: 0.0263 - binary_accuracy: 0.9903
# Epoch 48/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0262 - binary_accuracy: 0.9904
# Epoch 49/100
# 35040/35040 [==============================] - 5s 136us/step - loss: 0.0258 - binary_accuracy: 0.9906
# Epoch 50/100
# 35040/35040 [==============================] - 5s 137us/step - loss: 0.0257 - binary_accuracy: 0.9903
# Epoch 51/100
# 35040/35040 [==============================] - 5s 144us/step - loss: 0.0255 - binary_accuracy: 0.9906
# Epoch 52/100
# 35040/35040 [==============================] - 5s 139us/step - loss: 0.0253 - binary_accuracy: 0.9905
# Epoch 53/100
# 35040/35040 [==============================] - 5s 143us/step - loss: 0.0252 - binary_accuracy: 0.9908
# Epoch 54/100
# 35040/35040 [==============================] - 5s 146us/step - loss: 0.0249 - binary_accuracy: 0.9910 4s - loss: 0.0279 - binary_accuracy: 0.98
# Epoch 55/100
# 35040/35040 [==============================] - 5s 149us/step - loss: 0.0250 - binary_accuracy: 0.9908 2s - los
# Epoch 56/100
# 35040/35040 [==============================] - 5s 143us/step - loss: 0.0247 - binary_accuracy: 0.9909
# Epoch 57/100
# 35040/35040 [==============================] - 5s 139us/step - loss: 0.0251 - binary_accuracy: 0.9909
# Epoch 58/100
# 35040/35040 [==============================] - 5s 152us/step - loss: 0.0247 - binary_accuracy: 0.9911 2s - loss: 0.0240
# Epoch 59/100
# 35040/35040 [==============================] - 5s 149us/step - loss: 0.0248 - binary_accuracy: 0.9908
# Epoch 60/100
# 35040/35040 [==============================] - 5s 140us/step - loss: 0.0248 - binary_accuracy: 0.9910
# Epoch 61/100
# 35040/35040 [==============================] - 5s 148us/step - loss: 0.0243 - binary_accuracy: 0.9910
# Epoch 62/100
# 35040/35040 [==============================] - 5s 144us/step - loss: 0.0243 - binary_accuracy: 0.9911
# Epoch 63/100
# 35040/35040 [==============================] - 5s 143us/step - loss: 0.0241 - binary_accuracy: 0.9913
# Epoch 64/100
# 35040/35040 [==============================] - 5s 145us/step - loss: 0.0241 - binary_accuracy: 0.9912 0s - loss: 0.0240 - binary_accu
# Epoch 65/100
# 35040/35040 [==============================] - 5s 145us/step - loss: 0.0242 - binary_accuracy: 0.9910
# Epoch 66/100
# 35040/35040 [==============================] - 5s 147us/step - loss: 0.0238 - binary_accuracy: 0.9912
# Epoch 67/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.0239 - binary_accuracy: 0.9912
# Epoch 68/100
# 35040/35040 [==============================] - 5s 149us/step - loss: 0.0238 - binary_accuracy: 0.9908
# Epoch 69/100
# 35040/35040 [==============================] - 5s 148us/step - loss: 0.0237 - binary_accuracy: 0.9912
# Epoch 70/100
# 35040/35040 [==============================] - 5s 150us/step - loss: 0.0236 - binary_accuracy: 0.9911
# Epoch 71/100
# 35040/35040 [==============================] - 5s 144us/step - loss: 0.0237 - binary_accuracy: 0.9910
# Epoch 72/100
# 35040/35040 [==============================] - 5s 150us/step - loss: 0.0238 - binary_accuracy: 0.9915
# Epoch 73/100
# 35040/35040 [==============================] - 5s 149us/step - loss: 0.0235 - binary_accuracy: 0.9912
# Epoch 74/100
# 35040/35040 [==============================] - 5s 150us/step - loss: 0.0234 - binary_accuracy: 0.9911
# Epoch 75/100
# 35040/35040 [==============================] - 5s 146us/step - loss: 0.0233 - binary_accuracy: 0.9912
# Epoch 76/100
# 35040/35040 [==============================] - 5s 148us/step - loss: 0.0235 - binary_accuracy: 0.9913
# Epoch 77/100
# 35040/35040 [==============================] - 5s 150us/step - loss: 0.0235 - binary_accuracy: 0.9912
# Epoch 78/100
# 35040/35040 [==============================] - 5s 148us/step - loss: 0.0232 - binary_accuracy: 0.9912
# Epoch 79/100
# 35040/35040 [==============================] - 5s 147us/step - loss: 0.0232 - binary_accuracy: 0.9913
# Epoch 80/100
# 35040/35040 [==============================] - 5s 148us/step - loss: 0.0233 - binary_accuracy: 0.9914
# Epoch 81/100
# 35040/35040 [==============================] - 5s 151us/step - loss: 0.0231 - binary_accuracy: 0.9913
# Epoch 82/100
# 35040/35040 [==============================] - 5s 148us/step - loss: 0.0232 - binary_accuracy: 0.9914
# Epoch 83/100
# 35040/35040 [==============================] - 5s 146us/step - loss: 0.0231 - binary_accuracy: 0.9914
# Epoch 84/100
# 35040/35040 [==============================] - 5s 149us/step - loss: 0.0230 - binary_accuracy: 0.9915
# Epoch 85/100
# 35040/35040 [==============================] - 5s 142us/step - loss: 0.0227 - binary_accuracy: 0.9914
# Epoch 86/100
# 35040/35040 [==============================] - 5s 138us/step - loss: 0.0231 - binary_accuracy: 0.9912
# Epoch 87/100
# 35040/35040 [==============================] - 5s 131us/step - loss: 0.0231 - binary_accuracy: 0.9913
# Epoch 88/100
# 35040/35040 [==============================] - 5s 144us/step - loss: 0.0229 - binary_accuracy: 0.9913
# Epoch 89/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0229 - binary_accuracy: 0.9914
# Epoch 90/100
# 35040/35040 [==============================] - 5s 134us/step - loss: 0.0228 - binary_accuracy: 0.9912
# Epoch 91/100
# 35040/35040 [==============================] - 5s 139us/step - loss: 0.0227 - binary_accuracy: 0.9913
# Epoch 92/100
# 35040/35040 [==============================] - 5s 143us/step - loss: 0.0227 - binary_accuracy: 0.9914
# Epoch 93/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0227 - binary_accuracy: 0.9913
# Epoch 94/100
# 35040/35040 [==============================] - 5s 134us/step - loss: 0.0228 - binary_accuracy: 0.9913
# Epoch 95/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0229 - binary_accuracy: 0.9913
# Epoch 96/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0225 - binary_accuracy: 0.9914
# Epoch 97/100
# 35040/35040 [==============================] - 5s 134us/step - loss: 0.0231 - binary_accuracy: 0.9912
# Epoch 98/100
# 35040/35040 [==============================] - 5s 137us/step - loss: 0.0224 - binary_accuracy: 0.9914
# Epoch 99/100
# 35040/35040 [==============================] - 5s 141us/step - loss: 0.0225 - binary_accuracy: 0.9914
# Epoch 100/100
# 35040/35040 [==============================] - 5s 138us/step - loss: 0.0225 - binary_accuracy: 0.9915
# 11681/11681 [==============================] - 2s 155us/step
# // 평가 : [2.377586632123774, 0.8494991660118103]
# // 모델 저장 완료

# %%
model2 = load_model("model.h5")

# %%
def predict_risk(doc, word_index):
    okt = Okt()
    def tokenize(doc):
        return ['/'.join(t) for t in okt.pos(doc, norm=True, stem=True)]
        # norm은 정규화(오타 및 띄어쓰기 교정), stem은 근어화
    token = tokenize(doc)
    data = np.expand_dims(np.asarray([token.count(word) for word in word_index]).astype('float32'), axis=0)
    score = float(model.predict(data))
    print("[{}]의 위험 지수는 {:.2f}% 입니다.\n".format(doc, score * 100))

# %%
predict_risk("오늘 정말 좋은 날이네요", word_index)
# Out:
# [오늘 정말 좋은 날이네요]의 위험 지수는 0.00% 입니다.
